# %% [markdown]
# ### 295. Find Median From Data Stream - 2/24/2024

# %%
"""
2nd Try
"""
class MedianFinder:
    """
    We will have two heaps 
        - small -> maxHeap
        - large -> minHeap

    We need to satisfy two conditions everytime
        1. len difference between small and large isn't bigger than 1
            - using len()
        2. every element in the 'small' is bigger than every element in the 'large' 
            - using heapq.heappop()

        NOTE python by default implements a minHeap,
            - so to implement an maxHeap we have to use -1
    """

    def __init__(self):
        self.small, self.large = [], []
        

    def addNum(self, num: int) -> None:
        # by defeault we will add nums to small heap
        heapq.heappush(self.small, -1* num)

        # Checking for the 2nd Condition
        if (self.small and self.large and (-1 * self.small[0] > self.large[0])):
            val = -1 * heapq.heappop(self.small)
            heapq.heappush(self.large, val)

        # Checking for the 1st Condition
        if (len(self.small) > len(self.large) + 1):
            val = -1 * heapq.heappop(self.small)
            heapq.heappush(self.large, val)

        if (len(self.large) > len(self.small) + 1):
            val = heapq.heappop(self.large)
            heapq.heappush(self.small, -1 * val)

        

    def findMedian(self) -> float:
        if len(self.small) > len(self.large):
            return -1 * self.small[0]

        if len(self.large) > len(self.small):
            return self.large[0]

        return (-1 * self.small[0] + self.large[0]) / 2
        


# Your MedianFinder object will be instantiated and called as such:
# obj = MedianFinder()
# obj.addNum(num)
# param_2 = obj.findMedian()

# %%
"""
UMPIRE
Adding and Removing from the heap is 
    - O(log n) Operation

Accessing the Max or Min from the heap is
    - O(1) Operation

"""

class MedianFinder:
    def __init__(self):
        # Small is a Max Heap
        # Large is a Min Heap
        # Python by default creates a min Heap
            # So, to implement an max heap, we need to multiply by -1 
            # when pushining it to the heap
        self.small, self.large = [], []


    def addNum(self, num: int) -> None:
        heapq.heappush(small, -1 * num)

        # make sure every num small is <= every num is large
        if (self.small and self.large and (-1 * self.small[0])) > self.large[0]:
            val = -1 * heapq.heappop(self.small)
            heapq.heappush(self.large, val)

        # uneven size -> means that difference in length is more than 1
            if len(self.small) > len(self.large) + 1:
                val = -1 * heapq.heappop(self.small)
                heapq.heappush(self.large, val)

            if len(self.large) > len(small) + 1:
                val = heapq.heappop(self.large)
                heapq.heappush(self.small, -1 * val)

    def findMedian(self) -> float:
        if len(self.small) > len(self.large):
            return -1 * self.small[0]
        if len(self.large) > len(self.small):
            return self.small[0]
        
        return (-1 * self.small[0] + self.large[0]) / 2

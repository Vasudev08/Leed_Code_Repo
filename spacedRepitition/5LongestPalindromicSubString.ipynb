# %% [markdown]
# ### 5. Longest Palindromic Substring - 8/25/2024

# %%
############################### Improvement Table ###########################################
"""
Repitition # -  Time Taken   
1st Repetition - 48 mins - litlte help at the end, but got the idea and almost the implementation as well

"""

# %% [markdown]
# ### Model Answer

# %% [markdown]
# ### 1st Repitition

# %%
"""UMPIRE
U: given string s, return the longest palindromic substring
    output: substring

M: Two pointers + dynamic Programming

P:

1. create a empty dp list, where we are going to store the
len of the palindromic considering the current index as the starting point
 And we would have three cases to find max palindromc substring
 1.1 moving both left and right pointer outwards at the same time
 1.2 moving left pointer once, then moving both left and right pointer
 1.3 move rith pointer once, then move both left and right pointer

 DO it AGAIN, with more simplification


"""

class Solution:
    def longestPalindrome(self, s: str) -> str:

        # resLen = 0
        # resString = ""
        # dp = [0] * len(s)

        # def checkPalindrome(l, r):
        #     if l == 0:
        #         return
            
        #     if r == len(s) - 1:
        #         return 
            

        #     while (l >= 0 and r <= len(s) - 1 and s[l] == s[r]):
        #         l -= 1
        #         r += 1


        #     curLen = (r - l + 1)
            
        #     if curLen > resLen:
        #         resLen = curLen
        #         resString = s[l, r]


            



        # for i in range(len(s)):
        #     checkPalindrome(i - 1, i + 1)
        #     if s[i] == s[i + 1] and i + 1 <= len(s) - 1:
        #         checkPalindrome(i, i + 1)
        #     elif s[i] == s[i - 1] and i - 1 >= 0:
        #         checkPalindrome(i-1, i)


        # return resString

        
        resLen = 0
        resString = ""
        dp = [0] * len(s)

        def checkPalindrome(l, r):
            nonlocal resString
            nonlocal resLen


            while (l >= 0 and r <= len(s) - 1 and s[l] == s[r]):
                l -= 1
                r += 1

           

            curLen = (r - l - 1)
            if curLen > resLen:
                print("curLen: ", curLen)
                print("resLen: ", resLen)
                print("resString: ", s[l: r - 1])
                resLen = curLen
                resString = s[l+1: r]

        for i in range(len(s)):
            checkPalindrome(i - 1, i + 1)
            checkPalindrome(i, i + 1)
           


        return resString

        
            # check if current index letter either mathches with the left or right (even length Palindrome)
            # check for (odd length Pandimome)

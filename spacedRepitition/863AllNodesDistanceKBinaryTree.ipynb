# %% [markdown]
# ### 863. All Nodes Distance K in Binary Tree

# %%
############################### Improvement Table ###########################################
"""
Repitition # -  Time Taken   


"""

# %% [markdown]
# ### Model Answer

# %% [markdown]
# ### 1st Repitition

# %%
"""
UMPIRE

U: we have a binary tree and we are given three inputs
    Binary Tree : root,
    targetNode: target,
    kDistanceUnit: k

    we have to return values of nodes that are k spaces away from our target

M: dfs + bfs
dfs: for finding the target Node
bfs: for finding k distanced nodes

assumption: no repeated values
- no negative values
- we can safely assume, all nodes are connected, we have a single tree

P:

# Challening part
- going up the binary tree
    which can be done using child:parent dictionary or hashmap

1. create a hashMap where key: child, value: parent
2. use dfs to find the target node
3. use bfs to find node k distance way from targeNode



"""

# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, x):
#         self.val = x
#         self.left = None
#         self.right = None

class Solution:
    def distanceK(self, root: TreeNode, target: TreeNode, k: int) -> List[int]:
        hmap = defaultdict()
        vset = set()

        def bfs(node):
            level = k
            que = deque([node])

            while que and k > 0:
                levelSize = len(que)

                for _ in range(levelSize):
                    curNode = que.pop()

                    if curNode.left and curNode.left not in vset:
                        que.append(curNode.left)
                        vset.add(curNode.left)
                    if curNode.right and curNode.right not in vset:
                        que.append(curNode.right)
                        vset.add(curNode.right)
                    if curNode in hmap and curNode not in vset:
                        que.append(hmap[curNode])
                        vset.add(hmap[curNode])


                k -= 1

            return list(que)


    
        def dfs(node):
            if not node:
                return
            
            hmap[node.right] = node
            hmap[node.left] = node
        
        dfs(root)
        res = bfs(target)

        print(res)
        return []

# %% [markdown]
# ### Correct Implementation

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, x):
#         self.val = x
#         self.left = None
#         self.right = None

"""
needed little help in fixing the problem.
"""

class Solution:
    def distanceK(self, root: TreeNode, target: TreeNode, k: int) -> List[int]:
        hmap = defaultdict(TreeNode)
        vset = set()
        # vset.add(target)

        def bfs(node):
            # nonlocal k
            level = 0
            que = deque([node])
            vset.add(node)

            while que and level < k:
                levelSize = len(que)

                for _ in range(levelSize):
                    curNode = que.popleft()

                    if curNode.left and curNode.left not in vset:
                        que.append(curNode.left)
                        vset.add(curNode.left)
                    if curNode.right and curNode.right not in vset:
                        que.append(curNode.right)
                        vset.add(curNode.right)
                    if curNode in hmap and hmap[curNode] not in vset:
                        que.append(hmap[curNode])
                        vset.add(hmap[curNode])


                level += 1

            return list(que)


    
        def dfs(node):
            if not node:
                return
            
            if node.right:
                hmap[node.right] = node
                dfs(node.right)
            if node.left:
                hmap[node.left] = node
                dfs(node.left)
        
        dfs(root)
        temp = bfs(target)
        res = []
        for node in temp:
            res.append(node.val)


        print(len(res))
        return res

# %% [markdown]
# ### 2nd Reptition - 11/21/2024

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, x):
#         self.val = x
#         self.left = None
#         self.right = None

class Solution:
    def distanceK(self, root: TreeNode, target: TreeNode, k: int) -> List[int]:

        """
        UMPIRE:
        U: we are given a root of the binary tree, our job is to find the target node
        and return all the nodes which are k nodes away from it. this means left, right and parentNode as well

        M: dfs + for loop when we find our targetNode

        P:
        1. find create a map, which maps nodes to it's parent
        2. develop a dfs function traversing to find the targetNode
        3. Once the targetNode is found and return the True if found
        4. if True, we run the dfs k times

        """


        def mapParent(node, parent):
            if not node:
                return

            parentMap[node] = parent
            mapParent(node.left, node)
            mapParent(node.right, node)

        def kDistanceNode(node, distanceAway):
            if not node or node in traversed or distanceAway > k:
                return

            traversed.add(node)

            if distanceAway == k:
                res.append(node.val)
                return

            kDistanceNode(node.left, distanceAway + 1)
            kDistanceNode(node.right, distanceAway + 1)
            kDistanceNode(parentMap[node], distanceAway + 1)

            

        parentMap = {}
        traversed = set()
        mapParent(root, None)

        res = []
        kDistanceNode(target, 0)

        return res

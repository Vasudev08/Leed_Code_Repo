# %% [markdown]
# ### 191. Number of 1 Bits - 3/27/2024

# %%
"""
UMPIRE:


"""

# %%
#Import library
from IPython.display import Image
# Load image from local storage
Image(filename = "D:/Vasudev_Agarwal/Work_Fun/1_Texas_AM/1_Technical_Interview/Leed_Code_Repo/Images/Number_Of_Bits_191.jpg", width = 400, height = 500)

# %%
class Solution:
    def hammingWeight(self, n: int) -> int:
        res = 0

        while n:
            res += n % 2
            n = n >> 1
        return res

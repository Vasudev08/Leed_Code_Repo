# %% [markdown]
# ### 235. Lowest Common Ancestor Of A Binary Search

# %%
"""
3rd Try -
use the fact of binary tree
"""

cur = root

while cur:
    if p.val > cur.val and q.val > cur.val:
        cur = cur.right
    elif p.val < cur.val and q.val < cur.val:
        cur = cur.left
    else:
        return cur

# %%
"""
NOTE 1st Try idea and logic and implementatoin are good and should be build upon

2nd Try
- In populateMap function, we will have 'node, parent' as the parameter
    - which will make my life easier

"""


class Solution:
    def lowestCommonAncestor(self, root: 'TreeNode', p: 'TreeNode', q: 'TreeNode') -> 'TreeNode':
        
        def populateMap(node, parent):
            if node:
                nodeMap[node] = parent
                if node.left:
                    populateMap(node.left, node)
                if node.right:
                    populateMap(node.right, node)


        nodeMap = {}
        populateMap(root, None)

        ancestor_p = set()

        while p:
            ancestor_p.add(p)
            p = nodeMap[p]

        while q:
            if q in ancestor_p:
                return q
            q = nodeMap[q]

        return None

# %%
"""
UMPIRE:
U: given a binary tree, return LCA of two nodes, that is the lowest parent node,
- NOTE a node can be parent to itself
M: Hashmap + bfs; hashmap to store the parent link, this way we can go up in the tree
P:
- Create a helper function, that popalutes the hashmap with their parent node
- using While loop 
    - we check if hashmap[p] = q OR hashmap[p] == q
        in which case we return the parent node
    - check if hashmap[q] == hashmap[p]
        - if so, return that node
        - else continue the while loop until it becomes null (NOTE root node's parent is null)
"""

class Solution:
    def lowestCommonAncestor(self, root: 'TreeNode', p: 'TreeNode', q: 'TreeNode') -> 'TreeNode':

        def populateMap(node):
            if not node:
                return
            
            if node not in nodeMap:
                print("Hello")
                if node.left:
                    nodeMap[node.left] = node
                if node.right:
                    nodeMap[node.right] = node

            if node.left:
                populateMap(node.left)

            if node.right:
                populateMap(node.right)



        nodeMap = {root: None}
        populateMap(root)


        while (p and q):
            if nodeMap[p] == q:
                return nodeMap[p].val
            
            if nodeMap[q] == p:
                return nodeMap[q].val
            
            if nodeMap[q].val == nodeMap[p].val:
                return nodeMap[p].val
            
            p = nodeMap[p]
            q = nodeMap[q]

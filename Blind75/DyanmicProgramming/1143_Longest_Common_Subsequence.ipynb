# %% [markdown]
# ### 1143. Longest Common Subsequence

# %%
#Import library
from IPython.display import Image
# Load image from local storage
Image(filename = "D:/Vasudev_Agarwal/Work_Fun/1_Texas_AM/1_Technical_Interview/Leed_Code_Repo/Images/Longest_Subsequence_1.jpg", width = 400, height = 500)

# %%
#Import library
from IPython.display import Image
# Load image from local storage
Image(filename = "D:/Vasudev_Agarwal/Work_Fun/1_Texas_AM/1_Technical_Interview/Leed_Code_Repo/Images/Longest_Subsequence_2.jpg", width = 400, height = 500)

# %%
"""
UMPIRE: 
U: Given two strings 'text1' & 'text2' retun the longest common
        subsequence, if there is no common subsequence -> return 0

M: Hashmap, maybe dp (but I don't know to use it), 2D DP
NOTE: subsequence means they have to be continouse
    

P:
BRUTE FORCE WAY
1. create a hahamp for longest string
2. traverse through smaller string to find largest common subsequence in this string
"""

class Solution:
    def longestCommonSubsequence(self, text1: str, text2: str) -> int:

        dp = [[0 for j in range(len(text) + 1)] for i in range(len(text1) + 1)]

        for i in range(len(text1)-1, -1, -1):
            for j in range(len(text2) -1, -1, -1):
                if text1[i] == text2[j]:
                    dp[i][j] = 1 + dp[i + 1][j + 1]

                else:
                    dp[i][j] = max(dp[i][j + 1], dp[i + 1][j])

        return dp[0][0]

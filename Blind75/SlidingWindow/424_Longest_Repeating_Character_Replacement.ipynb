# %% [markdown]
# ### 424. Longest Repeating Character Replacement - 2/11/2024

# %%
"""
2 Try:
- the below implementation doesn't work as we are not taking into considersation
which character we are change. In the below impelementation we are assuming/
chaning the character that is pointed by the r pointer.
but in many cases we might we to change the i pointer which isn't possible to do
in the below implementation, so we entirely different appraoch
"""

"""
What Changed: O(n) running time
we know that a string is valid or meets the requirements when:
- no. of replacement in that string is < k
- In the below implementation our strings is constructed using 
- sliding window approach which means string is valid when
-: windowLen - replacemnet < k
- we can get the replacement character by knowing the frequence of each character
- in that window string and choose the max frequent character
- in that window string as we want to replace the least frequent character


"""

class Solution:
    def characterReplacement(self, s: str, k: int) -> int:
        count = {}
        res = 0

        maxf = 0
        l = 0

        for r in range(len(s)):
            count[s[r]] = 1 + count.get(s[r], 0)

            while (r - l + 1) - max(count.values()) > k:
                count[s[l]] -= 1                
                l += 1

            res = max(res, r - l + 1)

        return res
    



    class Solution:
    def characterReplacement(self, s: str, k: int) -> int:
        count = {}
        res = 0

        maxf = 0
        l = 0

        for r in range(len(s)):
            count[s[r]] = 1 + count.get(s[r], 0)
            maxf = max(maxf, count[s[r]])

            while (r - l + 1) - maxf > k:
                count[s[l]] -= 1                
                l += 1

            res = max(res, r - l + 1)

        return res

# %%
"""
UMPIRE:
U: Given an string s and an integer k, you can replace characters k times 
to find the longest repeating character
M: Sliding Window, two pointers
P: possible solution:
- Start the traversal of string s using two pointers pointing at the same spot
- increase the sec pointers and if the character match again increment the pointer
- if not, check if K > 0 if so, decrease the k by 1, increment the ponter
- until k == 0 or K < 0, at this point compare and store the longest string
"""


class Solution:
    def characterReplacement(self, s: str, k: int) -> int:
        # l, r = 0, 0
        mlen = 0

        for i in range(len(s)):
            tlen = 0
            r = i
            
            while (r < len(s)):

                if s[i] != s[r] and k > 0:
                    k -= 1
                elif s[i] != s[r] and k < 0:
                    break

                tlen += 1
                r += 1
            
            mlen = max(mlen, tlen)

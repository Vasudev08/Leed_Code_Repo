# %% [markdown]
# ### 23. Merge K Sorted Lists - 2/16/2024

# %%
"""
2nd Try we will refactor the code but my logic was on point
- in the 1st try we are poppping the element from the beginning of the list
- but in the 2nd try we are combinning two lists from the list
- i.e [l1, l2, l3, l4]
- In 2nd try: we are combingin l1 and l2, l3 and l4 and append them into the lists and continue the process until whil loop condition
"""

class Solution:
    def mergeKLists(self, lists: List[Optional[ListNode]]) -> Optional[ListNode]:
        if not lists or len(lists) == 0:
            return None
        
        while (len(lists) > 1):
            mergedLists = []

            for i in range(0, len(lists), 2):
                l1 = lists[i]
                l2 = lists[i + 1] if (i + 1) < len(lists) else None
                mergedLists.append(self.mergelists(l1, l2))

            lists = mergedLists

        return lists[0]
    
    def mergelists(self, l1, l2):
        dummy = ListNode()
        tail = dummy

        while l1 and l2:
            if l1.val < l2.val:
                tail.next = l1
                l1 = l1.next
            else:
                tail.next = l2
                l2 = l2.next
            tail = tail.next
        if l1:
            tail.next = l1
        if l2:
            tail.next = l2

        return dummy.next

# %%
"""
# We can use list as a queue and keep on combining until len(list) == 1
        # until then pop the first two linked list, combine them using sorted linked
        # we did that using a dummy linked list

"""

# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def mergeKLists(self, lists: List[Optional[ListNode]]) -> Optional[ListNode]:
        # We can use list as a queue and keep on combining until len(list) == 1
        # until then pop the first two linked list, combine them using sorted linked
        # we did that using a dummy linked list
        while len(lists) > 1:
            p1 = lists.pop(0)
            p2 = lists.pop(0)
            dummy = ListNode()
            tail = dummy

            if (p1 and not p2 and len(lists) >= 1):
                return p1
            elif (p2 and not p1 and len(lists) >= 1):
                return p2

            while (p1 and p2):
                if p2.val > p1.val:
                    tail.next = p1
                    p1 = p1.next
                else:
                    tail.next = p2
                    p2 = p2.next

                tail = tail.next

                if p1:
                    tail.next = p1
                elif p2:
                    print("Hello")
                    tail.next = p2 

            lists.append(dummy.next)

        print(lists)
        print(len(lists))
        if len(lists) == 1:
            res = lists.pop(0)
        else:
            res = None
        return res
